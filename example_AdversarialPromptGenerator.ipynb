# %%
# import
from AdversarialPromptGenerator import AdversarialPromptGenerator

# %% [markdown]
# ## Basic Usage

# %%
# class initialization
adv_prompt_generator = AdversarialPromptGenerator()

# %%
# getting the adversarial prompts (prompt + adv_suffix)
adversarial_suffix_path = "./adv_suffixes.pt"
all_prompts = adv_prompt_generator.get_from(adversarial_suffix_path)
all_prompts

# %%
len(all_prompts)

# %% [markdown]
# In `adv_suffixes.pt` ci sono 100 suffissi $\rightarrow$ 100 prompt

# %% [markdown]
# ## Custom Prompt or Tokenizer

# %%
# class initialization
custom_prompt = ...
custom_tokenizer_name = ... # HF model name
adv_prompt_generator = AdversarialPromptGenerator(
    prompt=custom_prompt,
    tokenizer_model_name=custom_tokenizer_name
)
